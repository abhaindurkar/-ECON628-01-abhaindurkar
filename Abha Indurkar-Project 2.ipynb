# %%
import pandas as pd
import numpy as np

# %%
India= pd.read_stata('/Users/abhaindurkar/Desktop/India fertility.dta')

# %%
India.head(5)
# Out:
#       state      dist      tehs  villn  hhnum  hhmember sc4c       sc5   sc6  \
# 0  TamilNad  Coimbato  Pollachi      1      8         4    2  mainlivg  wood
# 1  TamilNad  Coimbato  Pollachi      1     40         4    1   seproom  wood
# 2  TamilNad  Coimbato  Pollachi      1     64         4    2   seproom  wood
# 3  TamilNad  Coimbato  Pollachi      1     65         5  NaN       NaN   NaN
# 4  TamilNad  Coimbato  Pollachi      1     68         3  NaN       NaN   NaN
#
#         sc7   ...   hbjc hbjd  hbje      hbj2      hbj3      hbj4 hbj5  \
# 0  handpump   ...    NaN  NaN   NaN       NaN       NaN       NaN  NaN
# 1  handpump   ...    NaN  NaN   NaN       NaN  cooperat  reliable  1.0
# 2  handpump   ...     no   no   yes  noeffect  cooperat  reliable  8.0
# 3       NaN   ...    NaN  NaN   NaN       NaN       NaN       NaN  NaN
# 4       NaN   ...    NaN  NaN   NaN       NaN       NaN       NaN  NaN
#
#       hbj6 hbf6 hbevuse
# 0      NaN  NaN     NaN
# 1  Average  NaN     yes
# 2    Worse  NaN     yes
# 3      NaN  NaN     NaN
# 4      NaN  NaN     NaN
#
# [5 rows x 1517 columns]

# %%
India.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2446 entries, 0 to 2445
# Columns: 1517 entries, state to hbevuse
# dtypes: category(1295), float32(14), float64(202), int16(1), int8(3), object(2)
# memory usage: 7.0+ MB

# %%
India.info(6)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2446 entries, 0 to 2445
# Data columns (total 1517 columns):
# state       category
# dist        category
# tehs        category
# villn       int8
# hhnum       int16
# hhmember    int8
# sc4c        category
# sc5         category
# sc6         category
# sc7         category
# sc7a        category
# sc7bh       category
# sc7bm       float64
# sc8         category
# sc9         category
# sc10        category
# sc11        category
# sc12        category
# sc13        category
# sc14        category
# erkeyer     object
# emoddate    float32
# ere4        float32
# erg15a      category
# erk6t       float32
# erl7        object
# ernum       float64
# erstate     category
# erdist      category
# erteh       category
# ervill      float64
# erhno       float64
# erwlno      float64
# erday       float64
# ermonth     category
# erresult    category
# ervisit     float64
# era1h       float64
# era1m       float64
# erb1        category
# erb2        category
# erb3        category
# erb4        float64
# erb6a       float64
# erb6b       float64
# erb6c       float64
# erb6a1      float64
# erb6a2      float64
# erb6a3      float64
# erb8        category
# erb8a       category
# erb9        category
# erb10a      category
# erb10b      category
# erb10c      category
# erb10d      category
# erb11       category
# erb11a      category
# erb12       category
# erb12a      category
# erb13       category
# erb14       category
# erb14a      float64
# erb14b      float64
# erb15       float64
# erb16m      category
# erb16y      category
# erb17       category
# erb17a      float64
# erb17b      float64
# erb17c      category
# erb17dm     category
# erb17dy     category
# erb18       float64
# erb18a      category
# erb18bm     category
# erb18by     category
# erc1        category
# erc2        category
# erc3        float64
# erc4        float64
# erc5        category
# erc6        float64
# erc7        float64
# erc8        category
# erc9        float64
# erc10       float64
# erc11       float64
# erc12       category
# erc13       category
# erc13a      category
# erb13bs     float64
# erb13bi     float64
# e1c15a      float64
# e1c15b      category
# e1c15cm     category
# e1c15cy     float64
# e1c15d      category
# e1c15eu     category
# e1c15en     float64
# e1c15f      float64
# e1c15g      category
# e1c15gd     category
# e2c15a      float64
# e2c15b      category
# e2c15cm     category
# e2c15cy     float64
# e2c15d      category
# e2c15eu     category
# e2c15en     float64
# e2c15f      float64
# e2c15g      category
# e2c15gd     category
# e3c15a      float64
# e3c15b      category
# e3c15cm     category
# e3c15cy     float64
# e3c15d      category
# e3c15eu     category
# e3c15en     float64
# e3c15f      float64
# e3c15g      category
# e3c15gd     category
# e4c15a      float64
# e4c15b      category
# e4c15cm     category
# e4c15cy     float64
# e4c15d      category
# e4c15eu     category
# e4c15en     float64
# e4c15f      float64
# e4c15g      category
# e4c15gd     category
# e5c15a      float64
# e5c15b      category
# e5c15cm     category
# e5c15cy     float64
# e5c15d      category
# e5c15eu     category
# e5c15en     float64
# e5c15f      float64
# e5c15g      category
# e5c15gd     category
# e6c15a      float64
# e6c15b      category
# e6c15cm     category
# e6c15cy     float64
# e6c15d      category
# e6c15eu     category
# e6c15en     float64
# e6c15f      float64
# e6c15g      category
# e6c15gd     category
# e7c15a      float64
# e7c15b      category
# e7c15cm     category
# e7c15cy     float64
# e7c15d      category
# e7c15eu     category
# e7c15en     float64
# e7c15f      float64
# e7c15g      category
# e7c15gd     category
# e8c15a      float64
# e8c15b      category
# e8c15cm     category
# e8c15cy     float64
# e8c15d      category
# e8c15eu     category
# e8c15en     float64
# e8c15f      float64
# e8c15g      category
# e8c15gd     category
# e9c15a      float64
# e9c15b      category
# e9c15cm     category
# e9c15cy     float64
# e9c15d      category
# e9c15eu     category
# e9c15en     float64
# e9c15f      float64
# e9c15g      category
# e9c15gd     category
# e10c15a     float64
# e10c15b     category
# e10c15cm    category
# e10c15cy    float64
# e10c15d     category
# e10c15eu    category
# e10c15en    float64
# e10c15f     float64
# e10c15g     category
# e10c15gd    category
# e11c15a     float64
# e11c15b     category
# e11c15cm    category
# e11c15cy    float64
# e11c15d     category
# e11c15eu    category
# e11c15en    float64
# e11c15f     float64
# e11c15g     category
# e11c15gd    category
# e12c15a     float64
# e12c15b     category
# e12c15cm    category
# e12c15cy    float64
# e12c15d     category
# e12c15eu    category
# e12c15en    float64
# e12c15f     float64
# e12c15g     category
# e12c15gd    category
# e13c15a     float64
# e13c15b     category
# e13c15cm    category
# e13c15cy    float64
# e13c15d     category
# e13c15eu    category
# e13c15en    float64
# e13c15f     float64
# e13c15g     category
# e13c15gd    category
# e14c15a     float64
# e14c15b     category
# e14c15cm    category
# e14c15cy    float64
# e14c15d     category
# e14c15eu    category
# e14c15en    float64
# e14c15f     float64
# e14c15g     category
# e14c15gd    category
# e15c15a     float64
# e15c15b     category
# e15c15cm    category
# e15c15cy    float64
# e15c15d     category
# e15c15eu    category
# e15c15en    float64
# e15c15f     float64
# e15c15g     category
# e15c15gd    category
# erc17       category
# erc17a      category
# erc18       category
# erc18a      category
# erc18b      category
# erc19       category
# erc20       category
# erc20a      category
# erc21       category
# erc21a      category
# erc22       category
# erc22a      category
# erc23       category
# erc24       category
# erc24a      category
# erc24b      category
# erc25t      category
# erc25b      category
# erc25g      category
# erc26       category
# erd1a1      category
# erd1b1      category
# erd1c1      category
# erd1a2      category
# erd1b2      category
# erd1c2      category
# erd1a3      category
# erd1b3      category
# erd1c3      category
# erd1a4      category
# erd1b4      category
# erd1c4      category
# erd1a5      category
# erd1b5      category
# erd1c5      category
# erd1a6      category
# erd1b6      category
# erd1c6      category
# erd1a7      category
# erd1c7      category
# erd1a8      category
# erd1c8      category
# erd1a9      category
# erd1b9      category
# erd1c9      category
# erd1a10     category
# erd1b10     category
# erd1c10     category
# erd3        category
# erd4        category
# erd5        category
# erd5a       category
# erd6        category
# erd7        category
# e1e1a       float64
# e1e1bw      category
# e1e1by      category
# e1e1c       category
# e1e1d       category
# e1e1e       float64
# e1e1f       category
# e1e1g       category
# e2e1a       float64
# e2e1bw      category
# e2e1by      category
# e2e1c       category
# e2e1d       category
# e2e1e       float64
# e2e1f       category
# e2e1g       category
# e3e1a       float64
# e3e1bw      category
# e3e1by      category
# e3e1c       category
# e3e1d       category
# e3e1e       float64
# e3e1f       category
# e3e1g       category
# e4e1a       float64
# e4e1bw      category
# e4e1by      category
# e4e1c       category
# e4e1d       category
# e4e1e       float64
# e4e1f       category
# e4e1g       category
# e5e1a       float64
# e5e1bw      category
# e5e1by      category
# e5e1c       category
# e5e1d       category
# e5e1e       float64
# e5e1f       category
# e5e1g       category
# e6e1a       float64
# e6e1bw      category
# e6e1by      category
# e6e1c       category
# e6e1d       category
# e6e1e       float64
# e6e1f       category
# e6e1g       category
# e7e1a       float64
# e7e1bw      category
# e7e1by      category
# e7e1c       category
# e7e1d       category
# e7e1e       float64
# e7e1f       category
# e7e1g       category
# e8e1a       float64
# e8e1bw      category
# e8e1by      category
# e8e1c       category
# e8e1d       category
# e8e1e       float64
# e8e1f       category
# e8e1g       category
# e9e1a       float64
# e9e1bw      category
# e9e1by      category
# e9e1c       category
# e9e1d       category
# e9e1e       float64
# e9e1f       category
# e9e1g       category
# e10e1a      float64
# e10e1bw     category
# e10e1by     category
# e10e1c      category
# e10e1d      category
# e10e1e      float64
# e10e1f      category
# e10e1g      category
# e11e1a      float64
# e11e1bw     category
# e11e1by     category
# e11e1c      category
# e11e1d      category
# e11e1e      float64
# e11e1f      category
# e11e1g      category
# ere2_1      category
# ere2_2      category
# ere2_3      category
# ere2_4      category
# ere2_5      category
# ere2_6      category
# ere2_7      category
# ere2_8      category
# ere2_9      category
# ere2_10     category
# ere5        category
# ere6        category
# ere6a       category
# ere8        category
# ere9a1      float64
# ere9b1      category
# ere9c1      category
# ere9d1      float64
# ere9e1      category
# ere9f1      category
# ere9a2      float64
# ere9b2      category
# ere9c2      category
# ere9d2      float64
# ere9e2      category
# ere9f2      category
# ere9a3      float64
# ere9b3      category
# ere9c3      category
# ere9d3      float64
# ere9e3      category
# ere9f3      category
# ere9a4      float64
# ere9b4      category
# ere9c4      category
# ere9d4      float64
# ere9e4      category
# ere9f4      category
# ere9a5      float64
# ere9b5      category
# ere9c5      category
# ere9d5      float64
# ere9e5      category
# ere9f5      category
# ere9a6      float64
# ere9b6      category
# ere9c6      category
# ere9d6      float64
# ere9e6      category
# ere9f6      category
# ere9a7      float64
# ere9b7      category
# ere9c7      category
# ere9d7      float64
# ere9e7      category
# ere9f7      category
# ere9a8      float64
# ere9b8      category
# ere9c8      category
# ere9d8      float64
# ere9e8      category
# ere9f8      category
# ere9a9      float64
# ere9b9      category
# ere9c9      category
# ere9d9      float64
# ere9e9      category
# ere9f9      category
# ere9a10     float64
# ere9b10     category
# ere9c10     category
# ere9d10     float64
# ere9e10     category
# ere9f10     category
# ere9a11     float64
# ere9b11     category
# ere9c11     category
# ere9d11     float64
# ere9e11     category
# ere9f11     category
# ere10       category
# ere10a      category
# ere10b      category
# ere10c      category
# erf1        category
# erf1a       category
# erf2        category
# erf2a       category
# erf2b       category
# erf2c       category
# erf2d       category
# erf2e       category
# erf2f       category
# erf2g       category
# erf2h       category
# erf3        category
# erf3a       category
# erf4a1      category
# erf4a2      category
# erf4a3      category
# erf4a4      category
# erf4a5      category
# erf4a6      category
# erf4a7      category
# erf4a8      category
# erf4a9      category
# erf4a9a     category
# erf4b1      category
# erf4b2      category
# erf4b3      category
# erf4b4      category
# erf4b5      category
# erf4b6      category
# erf4b7      category
# erf4b8      category
# erf4b9      category
# erf4b9a     category
# erf4c1      category
# erf4c2      category
# erf4c3      category
# erf4c4      category
# erf4c5      category
# erf4c6      category
# erf4c7      category
# erf4c8      category
# erf4c9      category
# erf4c9a     category
# erf4d1      category
# erf4d2      category
# erf4d3      category
# erf4d4      category
# erf4d5      category
# erf4d6      category
# erf4d7      category
# erf4d8      category
# erf4d9      category
# erf4d9a     category
# erf4e1      category
# erf4e2      category
# erf4e3      category
# erf4e4      category
# erf4e5      category
# erf4e6      category
# erf4e7      category
# erf4e8      category
# erf4e9      category
# erf4e9a     category
# erf4f1      category
# erf4f2      category
# erf4f3      category
# erf4f4      category
# erf4f5      category
# erf4f6      category
# erf4f7      category
# erf4f8      category
# erf4f9      category
# erf4f9a     category
# erf4g1      category
# erf4g2      category
# erf4g3      category
# erf4g4      category
# erf4g5      category
# erf4g6      category
# erf4g7      category
# erf4g8      category
# erf4g9      category
# erf4g9a     category
# erf4h1      category
# erf4h2      category
# erf4h3      category
# erf4h4      category
# erf4h5      category
# erf4h6      category
# erf4h7      category
# erf4h8      category
# erf4h9      category
# erf4h9a     category
# erf4i1      category
# erf4i2      category
# erf4i3      category
# erf4i4      category
# erf4i5      category
# erf4i6      category
# erf4i7      category
# erf4i8      category
# erf4i9      category
# erf4i9a     category
# erf4j1      category
# erf4j2      category
# erf4j3      category
# erf4j4      category
# erf4j5      category
# erf4j6      category
# erf4j7      category
# erf4j8      category
# erf4j9      category
# erf4j9a     category
# erf4k1      category
# erf4k2      category
# erf4k3      category
# erf4k4      category
# erf4k5      category
# erf4k6      category
# erf4k7      category
# erf4k8      category
# erf4k9      category
# erf4k9a     category
# erf4l1      category
# erf4l2      category
# erf4l3      category
# erf4l4      category
# erf4l5      category
# erf4l6      category
# erf4l7      category
# erf4l8      category
# erf4l9      category
# erf4l9a     category
# erf4m1      category
# erf4m2      category
# erf4m3      category
# erf4m4      category
# erf4m5      category
# erf4m6      category
# erf4m7      category
# erf4m8      category
# erf4m9      category
# erf4m9a     category
# erf4n1      category
# erf4n2      category
# erf4n3      category
# erf4n4      category
# erf4n5      category
# erf4n6      category
# erf4n7      category
# erf4n8      category
# erf4n9      category
# erf4n9a     category
# erf5a1      category
# erf5a2      category
# erf5a3      category
# erf5a4      category
# erf5a5      category
# erf5a6      category
# erf5a7      category
# erf5a7a     category
# erf5b1      category
# erf5b2      category
# erf5b3      category
# erf5b4      category
# erf5b5      category
# erf5b6      category
# erf5b7      category
# erf5b7a     category
# erf5c1      category
# erf5c2      category
# erf5c3      category
# erf5c4      category
# erf5c5      category
# erf5c6      category
# erf5c7      category
# erf5c7a     category
# erf5d1      category
# erf5d2      category
# erf5d3      category
# erf5d4      category
# erf5d5      category
# erf5d6      category
# erf5d7      category
# erf5d7a     category
# erf5e1      category
# erf5e2      category
# erf5e3      category
# erf5e4      category
# erf5e5      category
# erf5e6      category
# erf5e7      category
# erf5e7a     category
# erf5f1      category
# erf5f2      category
# erf5f3      category
# erf5f4      category
# erf5f5      category
# erf5f6      category
# erf5f7      category
# erf5f7a     category
# erf5g1      category
# erf5g2      category
# erf5g3      category
# erf5g4      category
# erf5g5      category
# erf5g6      category
# erf5g7      category
# erf5g7a     category
# erf5h1      category
# erf5h2      category
# erf5h3      category
# erf5h4      category
# erf5h5      category
# erf5h6      category
# erf5h7      category
# erf5h7a     category
# erf5i1      category
# erf5i2      category
# erf5i3      category
# erf5i4      category
# erf5i5      category
# erf5i6      category
# erf5i7      category
# erf5i7a     category
# erf5j1      category
# erf5j2      category
# erf5j3      category
# erf5j4      category
# erf5j5      category
# erf5j6      category
# erf5j7      category
# erf5j7a     category
# erf5k1      category
# erf5k2      category
# erf5k3      category
# erf5k4      category
# erf5k5      category
# erf5k6      category
# erf5k7      category
# erf5k7a     category
# erf5l1      category
# erf5l2      category
# erf5l3      category
# erf5l4      category
# erf5l5      category
# erf5l6      category
# erf5l7      category
# erf5l7a     category
# erf5m1      category
# erf5m2      category
# erf5m3      category
# erf5m4      category
# erf5m5      category
# erf5m6      category
# erf5m7      category
# erf5m7a     category
# erf5n1      category
# erf5n2      category
# erf5n3      category
# erf5n4      category
# erf5n5      category
# erf5n6      category
# erf5n7      category
# erf5n7a     category
# fearhus     category
# fearfreq    category
# beatresp    category
# beathhw     category
# beatdisb    category
# beatdrk     category
# beathitc    category
# husbbeat    category
# beatoft     category
# presentf    category
# erg1        category
# erg2        category
# erg3        category
# erg4        category
# erg5        category
# erg6        category
# erg7        category
# erg8        category
# erg10       category
# erg10a      category
# erg11       category
# erg12       category
# erg13       category
# erg14       category
# erg14a      float64
# erg14b      float64
# erg15       category
# goldmr      category
# silvmr      category
# landmr      category
# housemr     category
# carmr       category
# tvmar       category
# frmar       category
# furnmar     category
# utmar       category
# radmar      category
# bikemar     category
# anmmar      category
# clthmar     category
# dowry       category
# landowry    category
# sayldwry    category
# jewldwry    category
# sayjdwry    category
# cashdwry    category
# saycsdry    category
# cardowry    category
# tvdowry     category
# frdowry     category
# furdowry    category
# utdowry     category
# raddowry    category
# bikdowry    category
# andowry     category
# cldowry     category
# presentg    category
# prmhous     category
# premmart    category
# prephc      category
# prefield    category
# precomc     category
# prefrnd     category
# prefair     category
# prmtmpl     category
# prmvill     category
# alnmarkt    category
# alnphc      category
# alnfield    category
# alncommc    category
# alnfrnd     category
# alnfair     category
# alntmpl     category
# alnvill     category
# ghunghat    category
# ghhusb      category
# ghfil       category
# ghmil       category
# ghbil       category
# ghsil       category
# ghmen       category
# ghhome      category
# ghvill      category
# ghoutvil    category
# uncohusb    category
# uncofil     category
# uncomil     category
# uncobil     category
# uncosil     category
# uncomem     category
# fammeal     category
# ustrend     category
# impeduc     category
# huslylty    category
# discmny     category
# disccom     category
# discch      category
# discfp      category
# moredch     category
# sonschl     category
# dauschl     category
# relmil      category
# oasoncr     category
# oasonsck    category
# oasonfin    category
# oadaucr     category
# oadausck    category
# oadaufin    category
# hoason      category
# hoadau      category
# hoarel      category
# hoasavig    category
# hoaland     category
# hoarent     category
# hoaearn     category
# hoagovt     category
# hoaoth      category
# decsman     category
# divlab      category
# hsbhw       category
# hsbtime     category
# moutwk      category
# hlnoch      category
# hlwdsrp     category
# hlwhhwk     category
# hlwdsbt     category
# hlwbtch     category
# hlwdrkd     category
# hlwsex      category
# wlnoch      category
# wlhdsrp     category
# wlhelon     category
# wlhbtch     category
# wlbtwf      category
# wlhdrkd     category
# wlhsex      category
# presenth    category
# whygung     category
# whymred     float64
# erj1        float64
# erj2m       category
# erj2y       category
# erj3        category
# erj3a       category
# erj4        category
# erj5        category
# erj5a       category
# erj6        category
# erj6a       category
# erj7        category
# erj7a       category
# erj7b       float64
# erj7c       float64
# erj8        category
# erj8a       category
# erj9        category
# erj10       float64
# erj11       category
# erj12       category
# erj13       float64
# erj14       category
# radio       category
# tv          category
# bicycle     category
# mtrbike     category
# clock       category
# fan         category
# fridge      category
# auto        category
# sewmach     category
# iron        category
# stereo      category
# furntre     category
# erk2        category
# erk3        category
# erk4        float64
# erk5        category
# erk5a       category
# erk5b       category
# erk5c       float64
# erk5d       category
# erk6a       category
# erk7        category
# erk8h       float64
# erk8m       float64
# erl1lno     float64
# erl1wght    float64
# erl2lno     float64
# erl2wght    float64
# erl3lno     float64
# erl3wght    float64
# erl3a       category
# erl3b       category
# erl3c       category
# erl3d       category
# erl3e       category
# erl4        category
# erl5        category
# erl6        category
# erl8        category
# relhead     category
# mominlaw    int8
# nosch1      category
# nosch2      category
# nosch3      category
# stopsch1    category
# stopsch2    category
# stopsch3    category
# workinc     category
# wrkincyr    category
# everuse     category
# momlit      category
# dadlit      category
# idno        float32
# hbc10am1    float32
# hbc10am2    float32
# hbc10am3    float32
# hbc10am4    float32
# hbc10t      float32
# hbc12a      float32
# hbc12c      float32
# hbc12d      float32
# hbc12f      float32
# hbc12t      float32
# hbg9a       category
# hbstate     category
# hbdist      category
# hbteh       category
# hbvill      float64
# hbhhno      float64
# hbwlno      float64
# hbhno       float64
# hbday       float64
# hbmonth     float64
# hbresult    category
# hbvisits    float64
# hbkeyer     float64
# hba1h       float64
# hba1m       float64
# hba2        float64
# hba3        category
# hba3a       category
# hba3b       category
# hba4        float64
# hba5m       category
# hba5y       category
# hba6        category
# hba7        float64
# hba9a       category
# hba9b       category
# hba9c       category
# hba9a1      category
# hba9a2      category
# hba9a3      category
# hba11       category
# hba11a      category
# hba12       category
# hba13a      category
# hba13b      category
# hba13c      category
# hba13d      category
# hba14       category
# hba14a      category
# hba15       category
# hba15a      category
# hba16       category
# hba17       category
# hba17a      float64
# hba17b      float64
# hbb1        category
# hbb1a       float64
# hbb1b       category
# hbb1c       category
# hbb1d       category
# hbb1e       float64
# hbb1f       category
# hbb1g       category
# hbb1a2      float64
# hbb1b2      category
# hbb1c2      category
# hbb1d2      category
# hbb1e2      float64
# hbb1f2      category
# hbb1g2      category
# hbb1a3      float64
# hbb1b3      category
# hbb1c3      category
# hbb1d3      category
# hbb1e3      float64
# hbb1f3      category
# hbb1g3      category
# hbb1a4      float64
# hbb1b4      category
# hbb1c4      category
# hbb1d4      category
# hbb1e4      float64
# hbb1f4      category
# hbb1g4      category
# hbb5        category
# hbc1        category
# hbc2        category
# hbc3        float64
# hbc4        category
# hbc4a       float64
# hbc4b       category
# hbc5        category
# hbc5a       float64
# hbc6        category
# hbc6a       float64
# hbc6b       category
# hbc7        category
# hbc8        category
# hbc8a       category
# hbc8b       float64
# hbc8cs      float64
# hbc8cl      float64
# hbc9        category
# hbc9a       category
# hbc9b       category
# hbc9c       category
# hbc9d       category
# hbc9e       category
# hbc9f       category
# hbc9g       category
# hbc9h       category
# hbc9i       category
# hbc10w      category
# hbc10ikp    category
# hbc10frm    category
# hbc10rem    category
# hbc10rnt    category
# hbc10am5    float64
# hbc10pen    category
# hbc10am6    float64
# hbc10oth    category
# hbc10am7    float64
# hbc11       category
# hbc12b      float64
# hbc12e      float64
# hbc12g      float64
# hbc12       category
# hbc13       category
# hbd1        category
# hbd2        category
# hbd2a       category
# hbd2b       category
# hbd3        category
# hbd3a       category
# hbd4a1      category
# hbd4a2      category
# hbd4a3      category
# hbd4a4      category
# hbd4a5      category
# hbd4a6      category
# hbd4a7      category
# hbd4a8      category
# hbd4a9      category
# hbd4a9a     category
# hbd4b1      category
# hbd4b2      category
# hbd4b3      category
# hbd4b4      category
# hbd4b5      category
# hbd4b6      category
# hbd4b7      category
# hbd4b8      category
# hbd4b9      category
# hbd4b9a     category
# hbd4c1      category
# hbd4c2      category
# hbd4c3      category
# hbd4c4      category
# hbd4c5      category
# hbd4c6      category
# hbd4c7      category
# hbd4c8      category
# hbd4c9      category
# hbd4c9a     category
# hbd4d1      category
# hbd4d2      category
# hbd4d3      category
# hbd4d4      category
# hbd4d5      category
# hbd4d6      category
# hbd4d7      category
# hbd4d8      category
# hbd4d9      category
# hbd4d9a     category
# hbd4e1      category
# hbd4e2      category
# hbd4e3      category
# hbd4e4      category
# hbd4e5      category
# hbd4e6      category
# hbd4e7      category
# hbd4e8      category
# hbd4e9      category
# hbd4e9a     category
# hbd4f1      category
# hbd4f2      category
# hbd4f3      category
# hbd4f4      category
# hbd4f5      category
# hbd4f6      category
# hbd4f7      category
# hbd4f8      category
# hbd4f9      category
# hbd4f9a     category
# hbd4g1      category
# hbd4g2      category
# hbd4g3      category
# hbd4g4      category
# hbd4g5      category
# hbd4g6      category
# hbd4g7      category
# hbd4g8      category
# hbd4g9      category
# hbd4g9a     category
# hbd4h1      category
# hbd4h2      category
# hbd4h3      category
# hbd4h4      category
# hbd4h5      category
# hbd4h6      category
# hbd4h7      category
# hbd4h8      category
# hbd4h9      category
# hbd4h9a     category
# hbd4i1      category
# hbd4i2      category
# hbd4i3      category
# hbd4i4      category
# hbd4i5      category
# hbd4i6      category
# hbd4i7      category
# hbd4i8      category
# hbd4i9      category
# hbd4i9a     category
# hbd4j1      category
# hbd4j2      category
# hbd4j3      category
# hbd4j4      category
# hbd4j5      category
# hbd4j6      category
# hbd4j7      category
# hbd4j8      category
# hbd4j9      category
# hbd4j9a     category
# hbd4k1      category
# hbd4k2      category
# hbd4k3      category
# hbd4k4      category
# hbd4k5      category
# hbd4k6      category
# hbd4k7      category
# hbd4k8      category
# hbd4k9      category
# hbd4k9a     category
# hbd4l1      category
# hbd4l2      category
# hbd4l3      category
# hbd4l4      category
# hbd4l5      category
# hbd4l6      category
# hbd4l7      category
# hbd4l8      category
# hbd4l9      category
# hbd4l9a     category
# hbd4m1      category
# hbd4m2      category
# hbd4m3      category
# hbd4m4      category
# hbd4m5      category
# hbd4m6      category
# hbd4m7      category
# hbd4m8      category
# hbd4m9      category
# hbd4m9a     category
# hbd4n1      category
# hbd4n2      category
# hbd4n3      category
# hbd4n4      category
# hbd4n5      category
# hbd4n6      category
# hbd4n7      category
# hbd4n8      category
# hbd4n9      category
# hbd4n9a     category
# hbd5a1      category
# hbd5a2      category
# hbd5a3      category
# hbd5a4      category
# hbd5a5      category
# hbd5a6      category
# hbd5a7      category
# hbd5a7a     category
# hbd5b1      category
# hbd5b2      category
# hbd5b3      category
# hbd5b4      category
# hbd5b5      category
# hbd5b6      category
# hbd5b7      category
# hbd5b7a     category
# hbd5c1      category
# hbd5c2      category
# hbd5c3      category
# hbd5c4      category
# hbd5c5      category
# hbd5c6      category
# hbd5c7      category
# hbd5c7a     category
# hbd5d1      category
# hbd5d2      category
# hbd5d3      category
# hbd5d4      category
# hbd5d5      category
# hbd5d6      category
# hbd5d7      category
# hbd5d7a     category
# hbd5e1      category
# hbd5e2      category
# hbd5e3      category
# hbd5e4      category
# hbd5e5      category
# hbd5e6      category
# hbd5e7      category
# hbd5e7a     category
# hbd5f1      category
# hbd5f2      category
# hbd5f3      category
# hbd5f4      category
# hbd5f5      category
# hbd5f6      category
# hbd5f7      category
# hbd5f7a     category
# hbd5g1      category
# hbd5g2      category
# hbd5g3      category
# hbd5g4      category
# hbd5g5      category
# hbd5g6      category
# hbd5g7      category
# hbd5g7a     category
# hbd5h1      category
# hbd5h2      category
# hbd5h3      category
# hbd5h4      category
# hbd5h5      category
# hbd5h6      category
# hbd5h7      category
# hbd5h7a     category
# hbd5i1      category
# hbd5i2      category
# hbd5i3      category
# hbd5i4      category
# hbd5i5      category
# hbd5i6      category
# hbd5i7      category
# hbd5i7a     category
# hbd5j1      category
# hbd5j2      category
# hbd5j3      category
# hbd5j4      category
# hbd5j5      category
# hbd5j6      category
# hbd5j7      category
# hbd5j7a     category
# hbd5k1      category
# hbd5k2      category
# hbd5k3      category
# hbd5k4      category
# hbd5k5      category
# hbd5k6      category
# hbd5k7      category
# hbd5k7a     category
# hbd5l1      category
# hbd5l2      category
# hbd5l3      category
# hbd5l4      category
# hbd5l5      category
# hbd5l6      category
# hbd5l7      category
# hbd5l7a     category
# hbd5m1      category
# hbd5m2      category
# hbd5m3      category
# hbd5m4      category
# hbd5m5      category
# hbd5m6      category
# hbd5m7      category
# hbd5m7a     category
# hbd5n1      category
# hbd5n2      category
# hbd5n3      category
# hbd5n4      category
# hbd5n5      category
# hbd5n6      category
# hbd5n7      category
# hbd5n7a     category
# hbd6a       category
# hbd6b       category
# hbd6c       category
# hbd6d       category
# hbd6e       category
# hbd7        category
# hbe1        category
# hbe2        category
# hbe3        float64
# hbe4        float64
# hbe5        category
# hbe6        float64
# hbe7        float64
# hbe8        category
# hbe9        float64
# hbe10       float64
# hbe11       float64
# hbe12       category
# hbe13       category
# hbe14       category
# hbe14a      category
# hbe14b      category
# hbe15       category
# hbe16       category
# hbe16a      category
# hbe16b      category
# hbe17t      category
# hbe17b      category
# hbe17g      category
# hbe18       category
# hbf1a       category
# hbf1b       category
# hbf1c       category
# hbf2a       category
# hbf2b       category
# hbf2c       category
# hbf3a       category
# hbf3b       category
# hbf3c       category
# hbf4a       category
# hbf4b       category
# hbf4c       category
# hbf5a       category
# hbf5b       category
# hbf5c       category
# hbf6a       category
# hbf6b       category
# hbf6c       category
# hbf7a       category
# hbf7c       category
# hbf8a       category
# hbf8c       category
# hbf9a       category
# hbf9b       category
# hbf9c       category
# hbf10a      category
# hbf10b      category
# hbf10c      category
# hbf3        category
# hbf4        category
# hbf5        category
# currmeth    category
# hbf17       category
# hbg1        category
# hbg2        category
# hbg3        category
# hbg4        category
# hbg5        category
# hbg6        category
# hbg6a       float64
# hbg7        category
# hbg8        category
# hbg9        category
# hbg9b1      category
# hbg9b2      category
# hbg9b3      category
# hbg9b4      category
# hbg9b5      category
# hbg9b6      category
# hbg9b7      category
# hbg9b8      category
# hbg9b9      category
# hbg9b10     category
# hbg9b11     category
# hbg9b12     category
# hbg9b13     category
# hbg9b14     category
# hbg10       category
# hbg11a1     category
# hbg11a2     category
# hbg11b1     category
# hbg11b2     category
# hbg11c1     category
# hbg11c2     category
# hbg11d1     category
# hbg11d2     category
# hbg11d3     category
# hbg11d4     category
# hbg11d5     category
# hbg11d6     category
# hbg11d7     category
# hbg11d8     category
# hbg11d9     category
# hbg12       category
# hbh1a       category
# hbh1b       category
# hbh1c       category
# hbh1d       category
# hbh1e       category
# hbh1f       category
# hbh1g       category
# hbh1h       category
# hbh1i       category
# hbh1a1      category
# hbh1a2      category
# hbh1a3      category
# hbh1a4      category
# hbh1a5      category
# hbh1a6      category
# hbh1a7      category
# hbh1a8      category
# hbh2        category
# hbh3        category
# hbh4        category
# hbh5        category
# hbh6a       category
# hbh6b       category
# hbh6c       category
# hbh6d       category
# hbh7        category
# hbh7b       category
# hbh7c       category
# hbh8a       category
# hbh8b       category
# hbh8c       category
# hbh8d       category
# hbh8e       category
# hbh8f       category
# hbh9a       category
# hbh9b       category
# hbh9c       category
# hbh9d       category
# hbh9e       category
# hbh9f       category
# hbh9g       category
# hbh9h       category
# hbh9i       category
# hbh10a      category
# hbh10b      category
# hbh10c      category
# hbh10d      category
# hbh10e      category
# hbh2a       float64
# hbh7a       float64
# hbh11a      category
# hbh11b      category
# hbh11c      category
# hbh11d      category
# hbh11e      category
# hbh11f      category
# hbh11g      category
# hbh12a      category
# hbh12b      category
# hbh12c      category
# hbh12d      category
# hbh12e      category
# hbh12f      category
# hbh12g      category
# hbh13       category
# hbh14h      float64
# hbh14m      float64
# hbja        category
# hbjb        category
# hbjc        category
# hbjd        category
# hbje        category
# hbj2        category
# hbj3        category
# hbj4        category
# hbj5        float64
# hbj6        category
# hbf6        category
# hbevuse     category
# dtypes: category(1295), float32(14), float64(202), int16(1), int8(3), object(2)
# memory usage: 7.0+ MB

# %%
India.shape
# Out:
# (2446, 1517)

# %%
India.drop(['erstate','erdist','ervill','erteh', 'erhno','erkeyer'], axis=1, inplace=True)

# %%
India.drop(['sc4c','sc5', 'sc7bm','emoddate', 'erl7' ,'ernum', 'erb10d','erb10c','erc12'], axis=1, inplace=True)

# %%
India = India.rename(index=str, columns={ "erb13": "Religion", "erb14": "SC-ST", "erb14a": "Castes", "erb14b": "Tribe", "erb15": "wife_age",})

# %%
India.tail()
# Out:
#          state    dist    tehs  villn  hhnum  hhmember      sc6       sc7  \
# 2441  UttPrade  Meerut  Bagpat     28   1309        10  cowdung  handpump
# 2442  UttPrade  Meerut  Bagpat     28   1316         6      NaN       NaN
# 2443  UttPrade  Meerut  Bagpat     28   1320         5      NaN       NaN
# 2444  UttPrade  Meerut  Bagpat     28   1327         6      NaN       NaN
# 2445  UttPrade  Meerut  Bagpat     28   1531         6  cowdung  handpump
#
#      sc7a sc7bh   ...    hbjc hbjd hbje hbj2      hbj3      hbj4 hbj5  \
# 2441    0   0.0   ...     NaN  NaN  NaN  NaN  cooperat  reliable  8.0
# 2442  NaN   NaN   ...     NaN  NaN  NaN  NaN       NaN       NaN  NaN
# 2443  NaN   NaN   ...     NaN  NaN  NaN  NaN       NaN       NaN  NaN
# 2444  NaN   NaN   ...     NaN  NaN  NaN  NaN       NaN       NaN  NaN
# 2445    0   0.0   ...     NaN  NaN  NaN  NaN  cooperat  reliable  1.0
#
#          hbj6      hbf6  hbevuse
# 2441   Better  pregnant       no
# 2442      NaN       NaN      NaN
# 2443      NaN       NaN      NaN
# 2444      NaN       NaN      NaN
# 2445  Average       NaN      yes
#
# [5 rows x 1502 columns]

# %%
India.isnull()
# Out:
#       state   dist   tehs  villn  hhnum hhmember    sc6    sc7   sc7a  sc7bh  \
# 0     False  False  False  False  False    False  False  False  False  False
# 1     False  False  False  False  False    False  False  False  False  False
# 2     False  False  False  False  False    False  False  False  False  False
# 3     False  False  False  False  False    False   True   True   True   True
# 4     False  False  False  False  False    False   True   True   True   True
# 5     False  False  False  False  False    False  False  False  False  False
# 6     False  False  False  False  False    False   True   True   True   True
# 7     False  False  False  False  False    False  False  False  False  False
# 8     False  False  False  False  False    False  False  False  False  False
# 9     False  False  False  False  False    False   True   True   True   True
# 10    False  False  False  False  False    False   True   True   True   True
# 11    False  False  False  False  False    False  False  False  False  False
# 12    False  False  False  False  False    False  False  False  False  False
# 13    False  False  False  False  False    False   True   True   True   True
# 14    False  False  False  False  False    False   True   True   True   True
# 15    False  False  False  False  False    False  False  False  False  False
# 16    False  False  False  False  False    False  False  False  False  False
# 17    False  False  False  False  False    False  False  False  False  False
# 18    False  False  False  False  False    False  False  False  False  False
# 19    False  False  False  False  False    False   True   True   True   True
# 20    False  False  False  False  False    False  False  False  False  False
# 21    False  False  False  False  False    False  False  False  False  False
# 22    False  False  False  False  False    False  False  False  False  False
# 23    False  False  False  False  False    False   True   True   True   True
# 24    False  False  False  False  False    False   True   True   True   True
# 25    False  False  False  False  False    False  False  False  False  False
# 26    False  False  False  False  False    False  False  False   True   True
# 27    False  False  False  False  False    False  False  False  False  False
# 28    False  False  False  False  False    False  False  False  False  False
# 29    False  False  False  False  False    False  False  False  False  False
# ...     ...    ...    ...    ...    ...      ...    ...    ...    ...    ...
# 2416  False  False  False  False  False    False  False  False  False  False
# 2417  False  False  False  False  False    False  False  False  False  False
# 2418  False  False  False  False  False    False  False  False  False  False
# 2419  False  False  False  False  False    False  False  False  False  False
# 2420  False  False  False  False  False    False  False  False  False  False
# 2421  False  False  False  False  False    False  False  False  False  False
# 2422  False  False  False  False  False    False  False  False  False  False
# 2423  False  False  False  False  False    False  False  False  False  False
# 2424  False  False  False  False  False    False  False  False  False  False
# 2425  False  False  False  False  False    False  False  False  False  False
# 2426  False  False  False  False  False    False  False  False  False  False
# 2427  False  False  False  False  False    False  False  False  False  False
# 2428  False  False  False  False  False    False  False  False  False  False
# 2429  False  False  False  False  False    False  False  False  False  False
# 2430  False  False  False  False  False    False  False  False  False  False
# 2431  False  False  False  False  False    False  False  False  False  False
# 2432  False  False  False  False  False    False  False  False  False  False
# 2433  False  False  False  False  False    False  False  False  False  False
# 2434  False  False  False  False  False    False  False  False  False  False
# 2435  False  False  False  False  False    False  False  False  False  False
# 2436  False  False  False  False  False    False  False  False  False  False
# 2437  False  False  False  False  False    False  False  False  False  False
# 2438  False  False  False  False  False    False  False  False  False  False
# 2439  False  False  False  False  False    False  False  False  False  False
# 2440  False  False  False  False  False    False  False  False  False  False
# 2441  False  False  False  False  False    False  False  False  False  False
# 2442  False  False  False  False  False    False   True   True   True   True
# 2443  False  False  False  False  False    False   True   True   True   True
# 2444  False  False  False  False  False    False   True   True   True   True
# 2445  False  False  False  False  False    False  False  False  False  False
#
#        ...     hbjc   hbjd   hbje   hbj2   hbj3   hbj4   hbj5   hbj6   hbf6  \
# 0      ...     True   True   True   True   True   True   True   True   True
# 1      ...     True   True   True   True  False  False  False  False   True
# 2      ...    False  False  False  False  False  False  False  False   True
# 3      ...     True   True   True   True   True   True   True   True   True
# 4      ...     True   True   True   True   True   True   True   True   True
# 5      ...     True   True   True   True  False  False  False  False   True
# 6      ...     True   True   True   True   True   True   True   True   True
# 7      ...     True   True   True   True  False  False  False  False   True
# 8      ...    False  False  False  False  False  False  False  False  False
# 9      ...     True   True   True   True   True   True   True   True   True
# 10     ...     True   True   True   True   True   True   True   True   True
# 11     ...     True   True   True   True  False  False  False  False   True
# 12     ...     True   True   True   True  False  False  False  False  False
# 13     ...     True   True   True   True   True   True   True   True   True
# 14     ...     True   True   True   True   True   True   True   True   True
# 15     ...     True   True   True   True  False  False  False  False   True
# 16     ...    False  False  False  False  False  False  False  False   True
# 17     ...     True   True   True   True  False  False  False  False   True
# 18     ...     True   True   True   True  False  False  False  False  False
# 19     ...     True   True   True   True   True   True   True   True   True
# 20     ...     True   True   True   True  False  False  False  False   True
# 21     ...    False  False  False  False  False  False  False  False  False
# 22     ...     True   True   True   True  False  False  False  False   True
# 23     ...     True   True   True   True   True   True   True   True   True
# 24     ...     True   True   True   True   True   True   True   True   True
# 25     ...     True   True   True   True  False  False  False  False  False
# 26     ...     True   True   True   True  False  False  False  False   True
# 27     ...     True   True   True   True  False  False  False  False  False
# 28     ...     True   True   True   True  False  False  False  False   True
# 29     ...    False  False  False  False  False  False  False  False  False
# ...    ...      ...    ...    ...    ...    ...    ...    ...    ...    ...
# 2416   ...     True   True   True   True  False  False  False  False  False
# 2417   ...     True   True   True   True  False  False  False  False  False
# 2418   ...     True   True   True   True  False  False  False  False   True
# 2419   ...     True   True   True   True  False  False  False  False   True
# 2420   ...     True   True   True   True  False  False  False  False   True
# 2421   ...    False  False  False  False  False  False  False  False  False
# 2422   ...     True   True   True   True  False  False  False  False   True
# 2423   ...     True   True   True   True  False  False  False  False   True
# 2424   ...     True   True   True   True  False  False  False  False   True
# 2425   ...     True   True   True   True  False  False  False  False  False
# 2426   ...     True   True   True   True  False  False  False  False   True
# 2427   ...     True   True   True   True  False  False  False  False  False
# 2428   ...    False  False  False  False  False  False  False  False   True
# 2429   ...    False  False  False  False  False  False  False  False   True
# 2430   ...    False  False  False  False  False  False  False  False  False
# 2431   ...     True   True   True   True  False  False  False  False  False
# 2432   ...     True   True   True   True  False  False  False  False  False
# 2433   ...     True   True   True   True  False  False  False  False  False
# 2434   ...     True   True   True   True  False  False  False  False  False
# 2435   ...    False  False  False  False  False  False  False  False  False
# 2436   ...     True   True   True   True  False  False  False  False  False
# 2437   ...    False  False  False  False  False  False  False  False  False
# 2438   ...     True   True   True   True  False  False  False  False   True
# 2439   ...     True   True   True   True  False  False  False  False  False
# 2440   ...     True   True   True   True  False  False  False  False  False
# 2441   ...     True   True   True   True  False  False  False  False  False
# 2442   ...     True   True   True   True   True   True   True   True   True
# 2443   ...     True   True   True   True   True   True   True   True   True
# 2444   ...     True   True   True   True   True   True   True   True   True
# 2445   ...     True   True   True   True  False  False  False  False   True
#
#      hbevuse
# 0       True
# 1      False
# 2      False
# 3       True
# 4       True
# 5      False
# 6       True
# 7      False
# 8      False
# 9       True
# 10      True
# 11     False
# 12     False
# 13      True
# 14      True
# 15     False
# 16     False
# 17     False
# 18     False
# 19      True
# 20     False
# 21     False
# 22     False
# 23      True
# 24      True
# 25     False
# 26     False
# 27     False
# 28     False
# 29     False
# ...      ...
# 2416   False
# 2417   False
# 2418   False
# 2419   False
# 2420   False
# 2421   False
# 2422   False
# 2423   False
# 2424   False
# 2425   False
# 2426   False
# 2427   False
# 2428   False
# 2429   False
# 2430   False
# 2431   False
# 2432   False
# 2433   False
# 2434   False
# 2435   False
# 2436   False
# 2437   False
# 2438   False
# 2439   False
# 2440   False
# 2441   False
# 2442    True
# 2443    True
# 2444    True
# 2445   False
#
# [2446 rows x 1502 columns]
